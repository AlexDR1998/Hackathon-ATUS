# %% [markdown]
# # Importing Libraries

# %%
from plotting_module import *
from statistics_module import *

# %matplotlib inline

# %% [markdown]
# # Loding data

# %%
respondents_column_codes = load_yaml(data_dir+"/respondents/column_codes.yaml")
respondents_value_codes = load_yaml(data_dir+"/respondents/value_codes.yaml")
respondent_data = pd.read_csv(data_dir+"/respondents/atusresp_0321.csv.gz")

# %%
activities_column_codes = load_yaml(data_dir+"/activity/column_codes.yaml")
activities_value_codes = load_yaml(data_dir+"/activity/value_codes.yaml")
activity_data = pd.read_csv(data_dir+"/activity/atusact_0321.csv.gz")

# %%
respondent_data['TRDTOCC1']

make_chart_pie('TRDTOCC1',respondents_value_codes, respondent_data)
# Out:
# {'Transportation and material moving occupations': 87328,
#  'Personal care and service occupations': 17941,
#  "Don't Know": 17567,
#  'Building and grounds cleaning and maintenance occupations': 13463,
#  'Community and social service occupations': 10342,
#  'Education, training, and library occupations': 8469,
#  'Construction and extraction occupations': 7799,
#  'Blank': 7401,
#  'Installation, maintenance, and repair occupations': 7349,
#  'Office and administrative support occupations': 6164,
#  'Healthcare support occupations': 5535,
#  'Protective service occupations': 5211,
#  'Food preparation and serving related occupations': 4845,
#  'Management occupations': 4573,
#  'Farming, fishing, and forestry occupations': 4319,
#  'Business and financial operations occupations': 3241,
#  'Arts, design, entertainment, sports, and media occupations': 3237,
#  'Legal occupations': 3115,
#  'Healthcare practitioner and technical occupations': 2877,
# ...

# %%
Minutes_year_loc(1, activity_data, title="Time spent in home")

# %%
Minutes_year_coarse(2, activity_data, title = "Time spent with household")

# %%
Minutes_year_precise(20102, activity_data, title = "Time spent with laundry")
